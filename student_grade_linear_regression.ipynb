# %% [markdown]
# # Student Grade Prediction using Linear Regression

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Loading the datasets

# %%
df = pd.read_csv('data/student_info.csv')
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Showing first 5 datas

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %% [markdown]
# ### Getting the information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %% [markdown]
# ### Finding the missing values in the data

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %% [markdown]
# ### Normalizing the null data

# %%
df2 = df.fillna(df.mean())
df2
# Out:
#      study_hours  student_marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.995949          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 195     7.530000          81.67
# 196     8.560000          84.68
# 197     8.940000          86.75
# 198     6.600000          78.05
# 199     8.350000          83.50
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Plotting a graph

# %%
plt.scatter(x=df2.study_hours, y=df2.student_marks, color='red', marker='*')
plt.show()

# %%
sns.heatmap(df2.corr(), annot=True, linewidths=3)
plt.show()

# %%
sns.barplot(data=df2, x=df2['study_hours'], y=df2['student_marks'])
plt.show()

# %% [markdown]
# ### Spliting the dataset

# %%
X = df2.drop("student_marks", axis='columns')
y = df2.drop("study_hours", axis='columns')
print(f'Shape of x: {X.shape}')
print(f'Shape of Y: {y.shape}')
# Out:
# Shape of x: (200, 1)
# Shape of Y: (200, 1)

# %%
sns.pairplot(df2, kind='reg')

# %% [markdown]
# ### Spliting the data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print("-"*20+"Training Data Shape"+"-"*20)
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print("-"*20+"Testing Data Shape"+"-"*20)
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# --------------------Training Data Shape--------------------
# Shape of X_train: (160, 1)
# Shape of y_train: (160, 1)
# --------------------Testing Data Shape--------------------
# Shape of X_test: (40, 1)
# Shape of y_test: (40, 1)

# %% [markdown]
# ## Selecting a model and train it
# ### Linear Regression
# #### y = m*x+c

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[3.93571802]]
# [50.44735504]

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[83.11381458],
#        [78.9025963 ],
#        [84.57003024],
#        [85.82946001],
#        [84.72745896],
#        [80.75238377],
#        [72.84159055],
#        [71.66087515],
#        [73.23516235],
#        [71.66087515],
#        [73.47130543],
#        [76.38373677],
#        [73.23516235],
#        [73.58937697],
#        [82.95638585],
#        [70.40144538],
#        [73.23516235],
#        [78.74516758],
#        [75.55723598],
#        [82.68088559],
#        [76.65923703],
#        [70.48015974],
#        [74.77009238],
#        [77.98143645],
#        [85.59331693],
#        [82.56281405],
#        [76.42309395],
#        [85.0423164 ],
#        [78.39095296],
#        [81.38209865],
#        [81.73631327],
#        [83.15317176],
#        [82.20859943],
#        [81.10659839],
#        [73.58937697],
#        [71.1492318 ],
#        [71.89701823],
#        [81.53952737],
#        [72.60544747],
#        [71.93637541]])

# %% [markdown]
# ### Creating a DataFrame for easy analysis

# %%
pd.DataFrame(np.c_[X_test, y_test, y_pred], columns=["study_hours", "student_original_marks", "student_predicted_marks"])
# Out:
#     study_hours  student_original_marks  student_predicted_marks
# 0      8.300000                   82.02                83.113815
# 1      7.230000                   77.55                78.902596
# 2      8.670000                   84.19                84.570030
# 3      8.990000                   85.46                85.829460
# 4      8.710000                   84.03                84.727459
# 5      7.700000                   80.81                80.752384
# 6      5.690000                   73.61                72.841591
# 7      5.390000                   70.90                71.660875
# 8      5.790000                   73.14                73.235162
# 9      5.390000                   73.02                71.660875
# 10     5.850000                   75.02                73.471305
# 11     6.590000                   75.37                76.383737
# 12     5.790000                   74.44                73.235162
# ...

# %% [markdown]
# ### Checking the Accuracy of our Model

# %%
lr.score(X_test, y_test)
# Out:
# 0.9514124242154464

# %%
plt.scatter(X_train, y_train)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_train, lr.predict(X_train), color='red')

# %% [markdown]
# ## Saving Our Machine Learning Model

# %%
import joblib
joblib.dump(lr, "Student_grade_prediction_model.pkl")
# Out:
# ['Student_grade_prediction_model.pkl']

# %%
model = joblib.load('Student_grade_prediction_model.pkl')

# %%
model.predict([[4]])[0][0]
# Out:
# d:\Python\ai_ml_algo\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(66.19022710353573)
